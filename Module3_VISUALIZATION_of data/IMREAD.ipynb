# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
from scipy import misc
import numpy as np
img=misc.imread('img.png')
img.shape
img
#plt.imshow(img)
img.shape
#plt.imshow(a)
a=img[[1]]
b=img[:,:,0]
#d = pd.DataFrame(np.random.randn(1000, 5), columns=['a', 'b', 'c', 'd', 'e'])
d = pd.DataFrame(np.random.randn(1000, 100))
plt.imshow(d.corr(),cmap=plt.cm.Blues, interpolation='nearest')
plt.colorbar()
