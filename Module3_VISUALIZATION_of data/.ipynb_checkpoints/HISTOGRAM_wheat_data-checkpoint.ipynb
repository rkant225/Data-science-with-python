# %%
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd

matplotlib.style.use('ggplot')

df=pd.read_csv('/home/rahul/Desktop/data_science/EDX_Data_Science/jupyter/Module3_VISUALIZATION_of data/Datasets/a.csv')
df.columns
df
df.asymmetry.plot.hist(title='Asymmetry')
plt.show()
