# %%
# %matplotlib notebook
#%matplotlib gtk

import matplotlib.pyplot as plt
import pandas as pd
import matplotlib
from mpl_toolkits.mplot3d import Axes3D
df=pd.read_excel('cement.xls')
df
df.columns=['cement','slag','ash','water','superplasticizer','co_aggr','fin_aggr','age','strength']
fig=plt.figure()
ax=fig.add_subplot(111,projection='3d')
ax.set_xlabel('cement')
ax.set_ylabel('water')
ax.set_zlabel('strength')
plt.suptitle('cement x water x strength')
ax.scatter(df.cement,df.water,df.strength,c='g',marker='.')
# Out:
# <img src="data:image/png;base64,...">

# %%
# %matplotlib notebook
#%matplotlib gtk

import matplotlib.pyplot as plt
import pandas as pd
import matplotlib
from mpl_toolkits.mplot3d import Axes3D
#df=pd.read_excel('cement.xls')
df=pd.read_csv('/home/rahul/Desktop/data_science/EDX_Data_Science/jupyter/Module3_VISUALIZATION_of data/Datasets/students.data',index_col=0)

df.columns
#df.columns=['cement','slag','ash','water','superplasticizer','co_aggr','fin_aggr','age','strength']
fig=plt.figure()
ax=fig.add_subplot(111,projection='3d')
ax.set_xlabel('First term')
ax.set_ylabel('Third term')
ax.set_zlabel('Daily Alocal')
plt.suptitle('cement x water x strength')
ax.scatter(df.G1,df.G3,df.Dalc,c='g',marker='.')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from sklearn.datasets import load_iris
from pandas.tools.plotting import parallel_coordinates
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
# Look pretty...
matplotlib.style.use('ggplot')
# If the above line throws an error, use plt.style.use('ggplot') instead
# Load up SKLearn's Iris Dataset into a Pandas Dataframe
df=pd.read_csv('/home/rahul/Desktop/data_science/EDX_Data_Science/jupyter/Module3_VISUALIZATION_of data/Datasets/students.data',index_col=0)


#data = load_iris()
#df = pd.DataFrame(data.data, columns=data.feature_names) 
#df['target_names'] = [data.target_names[i] for i in data.target]
# Parallel Coordinates Start Here:
df.columns
plt.figure()
parallel_coordinates(df, 'sex')
plt.show()
# Out:
# <img src="data:image/png;base64,...">
