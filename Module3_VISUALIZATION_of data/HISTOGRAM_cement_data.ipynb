# %%
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
from scipy.stats import norm
import numpy as np

matplotlib.style.use('ggplot')

df=pd.read_excel('/home/rahul/Desktop/data_science/EDX_Data_Science/jupyter/Module3_VISUALIZATION_of data/cement.xls')
df.columns=['cement','slag','ash','water','plasticizer','coarse','fine_agg','age','strength']
df.plot.scatter(x='strength',y='age')
plt.suptitle('age VS strength')
plt.xlabel('strength')
plt.ylabel('age')
plt.show()
