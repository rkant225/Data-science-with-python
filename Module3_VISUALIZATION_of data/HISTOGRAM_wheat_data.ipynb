# %%
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd

matplotlib.style.use('ggplot')

df=pd.read_csv('/home/rahul/Desktop/data_science/EDX_Data_Science/jupyter/Module3_VISUALIZATION_of data/Datasets/wheat.data')
df.columns
df
#df.asymmetry.plot.hist(title='Asymmetry',bins=6)
#plt.show()
df[df.wheat_type=='rosa'].asymmetry.plot.hist(alpha=.4)
df[df.wheat_type=='kama'].asymmetry.plot.hist(alpha=.4)
df[df.wheat_type=='canadian'].asymmetry.plot.hist(alpha=.4)
plt.show()
