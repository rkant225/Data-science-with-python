# %% [markdown]
# # DAT210x - Programming with Python for DS

# %% [markdown]
# ## Module2 - Lab5

# %% [markdown]
# Import and alias Pandas:

# %%
# .. your code here ..
import pandas as pd
df=pd.read_csv('/home/rahul/Desktop/data_science/EDX_Data_Science/jupyter/module_2_DATA_warangling/Datasets/census.data',header=-1)
df.columns=['Sno','education', 'age', 'capital-gain', 'race', 'capital-loss', 'hours-per-week', 'sex', 'classification']
df
# Out:
#          Sno     education  age capital-gain                race  \
# 0          0     Bachelors   39         2174               White
# 1          1     Bachelors   50            ?               White
# 2          2       HS-grad   38            ?               White
# 3          3          11th   53            ?               Black
# 4          4     Bachelors   28            0               Black
# 5          5       Masters   37            0               White
# 6          6           9th   49            0               Black
# 7          7       HS-grad   52            0               White
# 8          8       Masters   31        14084               White
# 9          9     Bachelors   42         5178               White
# 10        10  Some-college   37            0               Black
# 11        11     Bachelors   30            0  Asian-Pac-Islander
# 12        12     Bachelors   23            0               White
# 13        13       7th-8th   34            0  Amer-Indian-Eskimo
# 14        14       HS-grad   25            0               White
# 15        15       HS-grad   32            0               White
# 16        16          11th   38            0               White
# 17        17       Masters   43            0               White
# 18        18     Doctorate   40            0               White
# 19        19       HS-grad   54            0               Black
# 20        20           9th   35            0               Black
# 21        21          11th   43            0               White
# 22        22       HS-grad   59            0               White
# 23        23     Bachelors   56            0               White
# 24        24       HS-grad   19            0               White
# 25        25  Some-college   54            0  Asian-Pac-Islander
# 26        26       HS-grad   39            0               White
# 27        27       HS-grad   49            0               White
# 28        28  Some-college   20            0               Black
# 29        29     Bachelors   45            0               White
# ...      ...           ...  ...          ...                 ...
# 29506  29506       HS-grad   30            0               White
# 29507  29507          10th   32            0               White
# 29508  29508  Some-college   22            0               White
# 29509  29509       HS-grad   31            0               White
# 29510  29510       HS-grad   29            0               White
# 29511  29511     Bachelors   35            0               White
# 29512  29512     Bachelors   30            0  Asian-Pac-Islander
# 29513  29513     Doctorate   34            0               White
# 29514  29514     Bachelors   54            0  Asian-Pac-Islander
# 29515  29515  Some-college   37            0               White
# 29516  29516          12th   22            0               Black
# 29517  29517     Bachelors   34            0               White
# 29518  29518       HS-grad   30            0               Black
# 29519  29519     Bachelors   38        15020               Black
# 29520  29520     Doctorate   71            0               White
# 29521  29521       HS-grad   45            0               White
# 29522  29522       HS-grad   41            0               Black
# 29523  29523       HS-grad   72            0               White
# 29524  29524       Masters   31            0               Other
# 29525  29525       HS-grad   43            0               White
# 29526  29526  Some-college   43            0               White
# 29527  29527  Some-college   43            0               White
# 29528  29528          10th   32            0  Amer-Indian-Eskimo
# 29529  29529       Masters   32            0  Asian-Pac-Islander
# 29530  29530       Masters   53            0               White
# 29531  29531  Some-college   22            0               White
# 29532  29532       HS-grad   40            0               White
# 29533  29533       HS-grad   58            0               White
# 29534  29534       HS-grad   22            0               White
# 29535  29535       HS-grad   52        15024               White
#
#        capital-loss  hours-per-week     sex classification
# 0                 0              40    Male          <=50K
# 1                 0              13    Male          <=50K
# 2                 0              40    Male          <=50K
# 3                 0              40    Male          <=50K
# 4                 0              40  Female          <=50K
# 5                 0              40  Female          <=50K
# 6                 0              16  Female          <=50K
# 7                 0              45    Male           >50K
# 8                 0              50  Female           >50K
# 9                 0              40    Male           >50K
# 10                0              80    Male           >50K
# 11                0              40    Male           >50K
# 12                0              30  Female          <=50K
# 13                0              45    Male          <=50K
# 14                0              35    Male          <=50K
# 15                0              40    Male          <=50K
# 16                0              50    Male          <=50K
# 17                0              45  Female           >50K
# 18                0              60    Male           >50K
# 19                0              20  Female          <=50K
# 20                0              40    Male          <=50K
# 21             2042              40    Male          <=50K
# 22                0              40  Female          <=50K
# 23                0              40    Male           >50K
# 24                0              40    Male          <=50K
# 25                0              60    Male           >50K
# 26                0              80    Male          <=50K
# 27                0              40    Male          <=50K
# 28                0              44    Male          <=50K
# 29             1408              40    Male          <=50K
# ...             ...             ...     ...            ...
# 29506             0              55    Male          <=50K
# 29507             0              40    Male          <=50K
# 29508             0              40    Male          <=50K
# 29509             0              40  Female          <=50K
# 29510             0              35  Female          <=50K
# 29511             0              55  Female           >50K
# 29512             0              99  Female          <=50K
# 29513             0              60    Male           >50K
# 29514             0              50    Male           >50K
# 29515             0              39  Female          <=50K
# 29516             0              35    Male          <=50K
# 29517             0              55  Female           >50K
# 29518             0              46    Male          <=50K
# 29519             0              45  Female           >50K
# 29520             0              10    Male           >50K
# 29521             0              40  Female          <=50K
# 29522             0              32  Female          <=50K
# 29523             0              25    Male          <=50K
# 29524             0              30  Female          <=50K
# 29525             0              40    Male          <=50K
# 29526             0              40  Female          <=50K
# 29527             0              50    Male          <=50K
# 29528             0              40    Male          <=50K
# 29529             0              11    Male          <=50K
# 29530             0              40    Male           >50K
# 29531             0              40    Male          <=50K
# 29532             0              40    Male           >50K
# 29533             0              40  Female          <=50K
# 29534             0              20    Male          <=50K
# 29535             0              40  Female           >50K
#
# [29536 rows x 9 columns]

# %% [markdown]
# As per usual, load up the specified dataset, setting appropriate header labels.

# %%
# .. your code here ..

# %% [markdown]
# Excellent.
#
# Now, use basic pandas commands to look through the dataset. Get a feel for it before proceeding!
#
# Do the data-types of each column reflect the values you see when you look through the data using a text editor / spread sheet program? If you see `object` where you expect to see `int32` or `float64`, that is a good indicator that there might be a string or missing value or erroneous value in the column.

# %%
# .. your code here ..
import pandas as pd
df=pd.read_csv('/home/rahul/Desktop/data_science/EDX_Data_Science/jupyter/module_2_DATA_warangling/Datasets/census.data',header=-1)
df.columns=['Sno','education', 'age', 'capital-gain', 'race', 'capital-loss', 'hours-per-week', 'sex', 'classification']
df['capital-gain'].unique()
df['capital-gain']=pd.to_numeric(df['capital-gain'],errors='coerce')
df['capital-gain']=df['capital-gain'].fillna(0)
#df.dtypes
df[['age']]
df.age
# Out:
# 0        39
# 1        50
# 2        38
# 3        53
# 4        28
# 5        37
# 6        49
# 7        52
# 8        31
# 9        42
# 10       37
# 11       30
# 12       23
# 13       34
# 14       25
# 15       32
# 16       38
# 17       43
# 18       40
# 19       54
# 20       35
# 21       43
# 22       59
# 23       56
# 24       19
# 25       54
# 26       39
# 27       49
# 28       20
# 29       45
#          ..
# 29506    30
# 29507    32
# 29508    22
# 29509    31
# 29510    29
# 29511    35
# 29512    30
# 29513    34
# 29514    54
# 29515    37
# 29516    22
# 29517    34
# 29518    30
# 29519    38
# 29520    71
# 29521    45
# 29522    41
# 29523    72
# 29524    31
# 29525    43
# 29526    43
# 29527    43
# 29528    32
# 29529    32
# 29530    53
# 29531    22
# 29532    40
# 29533    58
# 29534    22
# 29535    52
# Name: age, dtype: int64

# %% [markdown]
# Try use `your_data_frame['your_column'].unique()` or equally, `your_data_frame.your_column.unique()` to see the unique values of each column and identify the rogue values.
#
# If you find any value that should be properly encoded to NaNs, you can convert them either using the `na_values` parameter when loading the dataframe. Or alternatively, use one of the other methods discussed in the reading.

# %%
# .. your code here ..

# %% [markdown]
# Look through your data and identify any potential categorical features. Ensure you properly encode any ordinal and nominal types using the methods discussed in the chapter.
#
# Be careful! Some features can be represented as either categorical or continuous (numerical). If you ever get confused, think to yourself what makes more sense generally---to represent such features with a continuous numeric type... or a series of categories?

# %%
# .. your code here ..

# %% [markdown]
# Lastly, print out your dataframe!

# %%
# .. your code here ..
