# %%
import numpy as np
import matplotlib.pyplot as plt
from os import listdir
import scipy.ndimage
import pandas as pd
import matplotlib
dfi=pd.DataFrame() 
count =0
for filename in listdir("/home/rahul/Desktop/data_science/EDX_Data_Science/jupyter/Module_4_TRANSFORMATION/Datasets/ALOI/32i/"):
    f="/home/rahul/Desktop/data_science/EDX_Data_Science/jupyter/Module_4_TRANSFORMATION/Datasets/ALOI/32i/"+filename 
    
    if filename.endswith(".png"):
        count=count+1  

#y = [100*[100*[]]]  
y=[[] for i in range(count)]

i=0
for filename in listdir("/home/rahul/Desktop/data_science/EDX_Data_Science/jupyter/Module_4_TRANSFORMATION/Datasets/ALOI/32i/"):
    if filename.endswith(".png"):
         f="/home/rahul/Desktop/data_science/EDX_Data_Science/jupyter/Module_4_TRANSFORMATION/Datasets/ALOI/32i/"+filename 
         y[i]=matplotlib.pyplot.imread(f)
         #print (f)
         
    
    i=i+1
       
dfi = pd.DataFrame(np.array(y[0].reshape(-1,1)))

for i in range(1,count):
    name=str(i)
    dfi[name]= pd.DataFrame(np.array(y[i].reshape(-1,1)))

    
#a=[df['1'],df['2']]
#a = np.reshape(dfi['1'], (144,192))
#a.shape
#plt.imshow(a)
#plt.show()
dfi=dfi.T
dfi
# Out:
#        0         1         2         3         4         5         6      \
# 0   0.015686  0.015686  0.015686  0.015686  0.015686  0.015686  0.015686
# 1   0.015686  0.015686  0.015686  0.015686  0.015686  0.015686  0.015686
# 2   0.015686  0.015686  0.015686  0.015686  0.015686  0.015686  0.015686
# 3   0.015686  0.015686  0.015686  0.015686  0.015686  0.015686  0.015686
# 4   0.015686  0.015686  0.015686  0.015686  0.015686  0.015686  0.015686
# 5   0.015686  0.015686  0.015686  0.015686  0.015686  0.015686  0.015686
# 6   0.015686  0.015686  0.015686  0.015686  0.015686  0.015686  0.015686
# 7   0.015686  0.015686  0.015686  0.015686  0.015686  0.015686  0.015686
# 8   0.015686  0.015686  0.015686  0.015686  0.015686  0.015686  0.015686
# 9   0.015686  0.015686  0.015686  0.011765  0.015686  0.015686  0.011765
# 10  0.015686  0.015686  0.015686  0.015686  0.015686  0.015686  0.015686
# 11  0.019608  0.015686  0.015686  0.015686  0.015686  0.015686  0.015686
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from os import listdir
import scipy.ndimage
import pandas as pd
import matplotlib
df=pd.DataFrame() 
count =0
for filename in listdir("/home/rahul/Desktop/data_science/EDX_Data_Science/jupyter/Module_4_TRANSFORMATION/Datasets/ALOI/32/"):
    f="/home/rahul/Desktop/data_science/EDX_Data_Science/jupyter/Module_4_TRANSFORMATION/Datasets/ALOI/32/"+filename 
    
    if filename.endswith(".png"):
        count=count+1  

#y = [100*[100*[]]]  
y=[[] for i in range(count)]

i=0
for filename in listdir("/home/rahul/Desktop/data_science/EDX_Data_Science/jupyter/Module_4_TRANSFORMATION/Datasets/ALOI/32/"):
    if filename.endswith(".png"):
         f="/home/rahul/Desktop/data_science/EDX_Data_Science/jupyter/Module_4_TRANSFORMATION/Datasets/ALOI/32/"+filename 
         y[i]=matplotlib.pyplot.imread(f)
         
    
    i=i+1
       
df = pd.DataFrame(np.array(y[0].reshape(-1,1)))

for i in range(1,count):
    name=str(i)
    df[name]= pd.DataFrame(np.array(y[i].reshape(-1,1)))

    
#a=[df['1'],df['2']]
a = np.reshape(df['1'], (144,192))
a.shape
#plt.imshow(a)
#plt.show()
df=df.T
df
# Out:
# /home/rahul/anaconda3/lib/python3.5/site-packages/numpy/core/fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)
#        0         1         2         3         4         5         6      \
# 0   0.015686  0.015686  0.015686  0.015686  0.015686  0.015686  0.015686
# 1   0.015686  0.015686  0.015686  0.015686  0.015686  0.015686  0.015686
# 2   0.015686  0.015686  0.015686  0.015686  0.015686  0.015686  0.011765
# 3   0.015686  0.015686  0.015686  0.015686  0.015686  0.015686  0.015686
# 4   0.015686  0.015686  0.015686  0.015686  0.015686  0.015686  0.015686
# 5   0.015686  0.015686  0.015686  0.015686  0.015686  0.015686  0.015686
# 6   0.015686  0.015686  0.015686  0.015686  0.015686  0.015686  0.019608
# 7   0.015686  0.015686  0.015686  0.015686  0.015686  0.015686  0.015686
# 8   0.015686  0.015686  0.015686  0.015686  0.015686  0.015686  0.015686
# ...

# %%
from sklearn import manifold
iso = manifold.Isomap(n_neighbors=6, n_components=2)
iso.fit(df)
manifold_temp = iso.transform(df)
T_isomap = pd.DataFrame(manifold_temp, columns=['Component1', 'Component2'])

# Left with 2 dimensions
T_isomap.shape
#T_isomap
# Out:
# (72, 2)

# %%
from sklearn import manifold
iso = manifold.Isomap(n_neighbors=6, n_components=2)
iso.fit(dfi)
manifold_temp = iso.transform(dfi)
T_isomapi = pd.DataFrame(manifold_temp, columns=['Component1', 'Component2'])

# Left with 2 dimensions
T_isomapi.shape
#T_isomapi
# Out:
# (12, 2)

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

fig = plt.figure()
fig.set_size_inches(10, 10)
ax = fig.add_subplot(111)
ax.set_title('2D Components from Isomap of Facial Images')
ax.set_xlabel('Component: 1')
ax.set_ylabel('Component: 2')
num_images=72

# Show 40 of the images ont the plot
x_size = (max(T_isomap['Component1']) - min(T_isomap['Component1'])) * 0.08
y_size = (max(T_isomap['Component2']) - min(T_isomap['Component2'])) * 0.08
for i in range(40):
    img_num = np.random.randint(0, num_images)
    x0 = T_isomap.loc[img_num, 'Component1'] - (x_size / 2.)
    y0 = T_isomap.loc[img_num, 'Component2'] - (y_size / 2.)
    x1 = T_isomap.loc[img_num, 'Component1'] + (x_size / 2.)
    y1 = T_isomap.loc[img_num, 'Component2'] + (y_size / 2.)
    img = df.iloc[img_num,:].values.reshape(144,192)
    ax.imshow(img, aspect='auto', cmap=plt.cm.gray, interpolation='nearest', zorder=100000, extent=(x0, x1, y0, y1))

# Show 2D components plot
ax.scatter(T_isomap['Component1'], T_isomap['Component2'], marker='.',alpha=0.7)

ax.set_ylabel('Up-Down Pose')
ax.set_xlabel('Right-Left Pose')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
matplotlib.style.use('ggplot')
fig = plt.figure()
fig.set_size_inches(10, 10)
ax = fig.add_subplot(111)
ax.set_title('2D Components from Isomap of Facial Images')
ax.set_xlabel('Component: 1')
ax.set_ylabel('Component: 2')
num_images=12

# Show 40 of the images ont the plot
x_size = (max(T_isomap['Component1']) - min(T_isomap['Component1'])) * 0.08
y_size = (max(T_isomap['Component2']) - min(T_isomap['Component2'])) * 0.08
for i in range(10):
    img_num = np.random.randint(0, num_images)
    x0 = T_isomapi.loc[img_num, 'Component1'] - (x_size / 2.)
    y0 = T_isomapi.loc[img_num, 'Component2'] - (y_size / 2.)
    x1 = T_isomapi.loc[img_num, 'Component1'] + (x_size / 2.)
    y1 = T_isomapi.loc[img_num, 'Component2'] + (y_size / 2.)
    img = df.iloc[img_num,:].values.reshape(144,192)
    ax.imshow(img, aspect='auto', cmap=plt.cm.gray, interpolation='nearest', zorder=100000, extent=(x0, x1, y0, y1))

    
    
# Show 40 of the images ont the plot
x_size = (max(T_isomap['Component1']) - min(T_isomap['Component1'])) * 0.08
y_size = (max(T_isomap['Component2']) - min(T_isomap['Component2'])) * 0.08
for i in range(40):
    img_num = np.random.randint(0, 72)
    x0 = T_isomap.loc[img_num, 'Component1'] - (x_size / 2.)
    y0 = T_isomap.loc[img_num, 'Component2'] - (y_size / 2.)
    x1 = T_isomap.loc[img_num, 'Component1'] + (x_size / 2.)
    y1 = T_isomap.loc[img_num, 'Component2'] + (y_size / 2.)
    img = df.iloc[img_num,:].values.reshape(144,192)
    ax.imshow(img, aspect='auto', cmap=plt.cm.gray, interpolation='nearest', zorder=100000, extent=(x0, x1, y0, y1))    
    
    
    
    
    

# Show 2D components plot
ax.scatter(T_isomapi['Component1'], T_isomapi['Component2'],c='r' ,marker='.',alpha=0.7)
ax.scatter(T_isomap['Component1'], T_isomap['Component2'],c='b' , marker='.',alpha=0.7)

ax.set_ylabel('Up-Down Pose')
ax.set_xlabel('Right-Left Pose')

plt.show()

# %%
from sklearn import manifold
iso = manifold.Isomap(n_neighbors=6, n_components=3)
iso.fit(df)
manifold_temp = iso.transform(df)
T= pd.DataFrame(manifold_temp, columns=['x','y','z'])

# Left with 2 dimensions
T.shape
# Out:
# (72, 3)

# %%
# %matplotlib notebook
#%matplotlib gtk

import matplotlib.pyplot as plt
import pandas as pd
import matplotlib
matplotlib.style.use('ggplot')


#ax=fig.add_subplot(111)

T.plot.scatter(x='x',y='y')
plt.show()

from mpl_toolkits.mplot3d import Axes3D

fig=plt.figure()
ax=fig.add_subplot(111,projection='3d')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
plt.suptitle('cement x water x strength')
ax.scatter(T.x,T.y,T.z,c='g',marker='.')
# Out:
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">

# %%
import math

import pandas as pd
import scipy.io
from sklearn import manifold
#Load the mattrix
mat = scipy.io.loadmat('Datasets/face_data.mat')
#convert to DataFrame
df = pd.DataFrame(mat['images']).T
#Find no. of images,no. of pixel,no. of pixels_per_dimension
num_images, num_pixels = df.shape
pixels_per_dimension = int(math.sqrt(num_pixels))

# Rotate the pictures
for idx in df.index:
    df.loc[idx] = df.loc[idx].values.reshape(pixels_per_dimension, pixels_per_dimension).T.reshape(-1)
df=df.T    
a = np.reshape(df[98], (64,64))
a.shape
plt.imshow(a)
plt.show()
# Out:
# /home/rahul/anaconda3/lib/python3.5/site-packages/numpy/core/fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
df
 

    
    
#df = pd.DataFrame(y)    
name='R'
df = pd.DataFrame(np.array(y[0].reshape(-1,1)))
df['a'] = pd.DataFrame(np.array(y[1].reshape(-1,1)))
df[name] = pd.DataFrame(np.array(y[2].reshape(-1,1)))
df

#plt.imshow(y[0])
#plt.show()
#y.shape

# %%
i=0
for filename in listdir("/home/rahul/Desktop/data_science/EDX_Data_Science/jupyter/Module_4_TRANSFORMATION/Datasets/ALOI/32/"):
    f="/home/rahul/Desktop/data_science/EDX_Data_Science/jupyter/Module_4_TRANSFORMATION/Datasets/ALOI/32/"+filename 
    print (f)
    if filename.endswith(".png"):
        print (i)
        arr[i]=np.append(arr,scipy.ndimage.imread(f),axis=0)
        print (ok)
        #arr[i]=scipy.ndimage.imread(f)
    i=i+1   
        #arr=np.append(arr,matplotlib.pyplot.imread(f))
arr.size
